# %%
# Standard imports
# Make sure you run this cell!
from __future__ import print_function, division
import numpy as np  # NumPy

# %matplotlib notebook
# %matplotlib notebook

# Set up Matplotlib
import matplotlib as mpl   
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})
print("Everything imported OK")
# Out:
# Everything imported OK

# %%
## LATENCY - DATAGRAMS
data = np.loadtxt(open("results.csv", "rb"), delimiter=",", skiprows=1)
fig = plt.figure()
axes = plt.gca()
# axes.set_ylim([0, 17])
ax = fig.add_subplot(1,1,1)
ax.plot(data[:,0], data[:,5])
ax.set_title("WebRTC - Adjusted CPU Usage vs Decoding Time", fontsize=13)
ax.set_xlabel("CPU Usage (Percentage)")
ax.set_ylabel("Decoding Time (seconds)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\apate\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Text(0,0.5,'Decoding Time (seconds)')

# %%
# ## LOSS - STREAMS
# # air = np.loadtxt('cherry_trees.txt')
# data = np.loadtxt(open("streams/results.csv", "rb"), delimiter=",", skiprows=1)
# # print(data[:,1])
# plt.ylim(0,6)
# fig = plt.figure()
# axes = plt.gca()
# axes.set_ylim([0, 10])
# ax4 = fig.add_subplot(1,1,1)
# ax4.plot(data[:,0], data[:,1], label="Actual Latency")
# ax4.plot(data[:,0], data[:,2], label="Perceived Latency")
# ax4.set_title("Streams - Adjusted Link Loss vs Latency", fontsize=13)
# ax4.set_xlabel("Loss (Percentage)")
# ax4.set_ylabel("Latency (seconds)")

# handles, labels = ax4.get_legend_handles_labels()
# ax4.legend(handles[::-1], labels[::-1])

# #
# #########################

# # small_data = np.loadtxt(open("streams/small_results.csv", "rb"), delimiter=",", skiprows=1)
# # fig = plt.figure()
# # axes = plt.gca()
# # axes.set_ylim([0, 130])
# # ax = fig.add_subplot(1,1,1)
# # ax.plot(small_data[:,0], small_data[:,1])
# # ax.plot(small_data[:,0], small_data[:,2])
# # ax.set_title("Streams - Adjusted Bandwidth (Small Measurements) vs Latency")
# # ax.set_xlabel("Bandwidth (Mbits)")
# # ax.set_ylabel("Latency (seconds)")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b5ef586ad544> in <module>()
#       1 ## LOSS - STREAMS
#       2 # air = np.loadtxt('cherry_trees.txt')
# ----> 3 data = np.loadtxt(open("streams/results.csv", "rb"), delimiter=",", skiprows=1)
#       4 # print(data[:,1])
#       5 plt.ylim(0,6)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'streams/results.csv'

# %%
data = np.loadtxt(open("results.csv", "rb"), delimiter=",", skiprows=1)
wt_dg_data = np.loadtxt(open("../../cpu/datagrams/results.csv", "rb"), delimiter=",", skiprows=1)
wt_streams_data = np.loadtxt(open("../../cpu/streams/results.csv", "rb"), delimiter=",", skiprows=1)
# print(data[:,1])
fig = plt.figure()
axes = plt.gca()
# axes.set_ylim([0, 6])
ax = fig.add_subplot(1,1,1)
ax.plot(data[:,0], data[:,5], label="WebRTC")
ax.plot(wt_dg_data[:,0], wt_dg_data[:,6], label="WebTransport (Datagrams)")
ax.plot(wt_streams_data[:,0], wt_streams_data[:,3], label="WebTransport (Streams)")
ax.set_title("All Builds - Adjusted CPU Usage vs Decoding Time", fontsize=13)
ax.set_xlabel("CPU Usage (percentage)")
ax.set_ylabel("Decoding Time (seconds)")

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1])
ax.legend(fontsize=9)

data = np.loadtxt(open("results.csv", "rb"), delimiter=",", skiprows=1)
wt_dg_data = np.loadtxt(open("../../cpu/datagrams/results.csv", "rb"), delimiter=",", skiprows=1)
wt_streams_data = np.loadtxt(open("../../cpu/streams/results.csv", "rb"), delimiter=",", skiprows=1)
# print(data[:,1])
fig = plt.figure()
axes = plt.gca()
# axes.set_ylim([0, 6])
ax = fig.add_subplot(1,1,1)
ax.plot(data[:,0], data[:,5], label="WebRTC")
ax.plot(wt_streams_data[:,0], wt_streams_data[:,3], label="WebTransport (Streams)")
ax.set_title("All Builds - Adjusted CPU Usage vs Decoding Time", fontsize=13)
ax.set_xlabel("CPU Usage (percentage)")
ax.set_ylabel("Decoding Time (seconds)")

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1])

# data = np.loadtxt(open("small_results.csv", "rb"), delimiter=",", skiprows=1)
# wt_bw_data = np.loadtxt(open("../../bandwidth/datagrams/small_results.csv", "rb"), delimiter=",", skiprows=1)
# wt_streams_data = np.loadtxt(open("../../bandwidth/streams/small_results.csv", "rb"), delimiter=",", skiprows=1)
# # print(data[:,1])
# fig = plt.figure()
# axes = plt.gca()
# # axes.set_ylim([0, 6])
# ax = fig.add_subplot(1,1,1)
# ax.plot(data[:,0], data[:,5], label="WebRTC")
# ax.plot(wt_bw_data[:,0], wt_bw_data[:,6], label="WebTransport (Datagrams)")
# ax.plot(wt_streams_data[:,0], wt_streams_data[:,3], label="WebTransport (Streams)")
# ax.set_title("All Builds - Adjusted Bandwidth (Small Measurements) vs Decoding Time")
# ax.set_xlabel("Bandwidth (Mbits)")
# ax.set_ylabel("Decoding Time (seconds)")

# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles[::-1], labels[::-1])

# small_data = np.loadtxt(open("datagrams/small_results.csv", "rb"), delimiter=",", skiprows=1)
# fig = plt.figure()
# axes = plt.gca()
# axes.set_ylim([0, 130])
# ax2 = fig.add_subplot(1,1,1)
# ax2.plot(small_data[:,0], small_data[:,2], label="Actual Latency")
# ax2.plot(small_data[:,0], small_data[:,3], label="Perceived Latency")
# ax2.set_title("Datagrams - Adjusted Bandwidth (Small Measurements) vs Latency")
# ax2.set_xlabel("Bandwidth (Mbits)")
# ax2.set_ylabel("Latency (seconds)")

# handles, labels = ax2.get_legend_handles_labels()
# ax2.legend(handles[::-1], labels[::-1])

# all_data = np.loadtxt(open("datagrams/results.csv", "rb"), delimiter=",", skiprows=1)
# fig = plt.figure()
# plt.autoscale(True)
# ax3 = fig.add_subplot(1,1,1)
# ax3.plot(all_data[:,0], all_data[:,5])
# ax3.set_title("Datagrams - Adjusted Bandwidth vs Loss")
# ax3.set_xlabel("Bandwidth (Mbits)")
# ax3.set_ylabel("Loss (percentage)")

# all_data = np.loadtxt(open("datagrams/small_results.csv", "rb"), delimiter=",", skiprows=1)
# fig = plt.figure()
# plt.autoscale(True)
# ax3 = fig.add_subplot(1,1,1)
# ax3.plot(all_data[:,0], all_data[:,5])
# ax3.set_title("Datagrams - Adjusted Bandwidth (Small Measurements) vs Loss")
# ax3.set_xlabel("Bandwidth (Mbits)")
# ax3.set_ylabel("Loss (percentage)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\apate\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# <img src="data:image/png;base64,..." width="640">
